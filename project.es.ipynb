# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
#        phone_realEstate                                       url_inmueble  \
# 0           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 1           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 2           916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 4           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# ...                 ...                                                ...
# 15330       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15331       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15332       912780348.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15333       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15334       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#        rooms  bathrooms  surface   price  ... level4Id level5Id level6Id  \
# 0        3.0        2.0    103.0  195000  ...        0        0        0
# 1        3.0        1.0      NaN   89000  ...        0        0        0
# 2        2.0        2.0     99.0  390000  ...        0        0        0
# 3        3.0        1.0     86.0   89000  ...        0        0        0
# 4        2.0        2.0    106.0  172000  ...        0        0        0
# ...      ...        ...      ...     ...  ...      ...      ...      ...
# 15330    2.0        1.0     96.0  259470  ...        0        0        0
# 15331    3.0        1.0    150.0  165000  ...        0        0        0
# 15332    4.0        2.0    175.0  495000  ...        0        0        0
# 15333    3.0        2.0    101.0  195000  ...        0        0        0
# 15334    3.0        2.0    152.0  765000  ...        0        0        0
#
#       level7Id level8Id accuracy          latitude          longitude zipCode  \
# 0            0        0        0  40,2948276786438  -3,44402412135624     NaN
# 1            0        0        1          40,28674           -3,79351     NaN
# 2            0        0        0  40,4115646786438  -3,90662252135624     NaN
# 3            0        0        0  40,2853785786438  -3,79508142135624     NaN
# 4            0        0        0  40,2998774864376  -3,45226301356237     NaN
# ...        ...      ...      ...               ...                ...     ...
# 15330        0        0        0          40,45416           -3,70286     NaN
# 15331        0        0        0          40,36652           -3,48951     NaN
# 15332        0        0        0          40,57444           -3,92124     NaN
# 15333        0        0        0          40,36967           -3,48105     NaN
# 15334        0        0        0          40,45773           -3,69068     NaN
#
#       customZone
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 15330        NaN
# 15331        NaN
# 15332        NaN
# 15333        NaN
# 15334        NaN
#
# [15335 rows x 37 columns]

# %%
for col in ds.columns:
    print(col)
# Out:
# Unnamed: 0
# id_realEstates
# isNew
# realEstate_name
# phone_realEstate
# url_inmueble
# rooms
# bathrooms
# surface
# price
# date
# description
# address
# country
# level1
# level2
# level3
# level4
# level5
# level6
# level7
# level8
# upperLevel
# countryId
# level1Id
# level2Id
# level3Id
# level4Id
# level5Id
# level6Id
# level7Id
# level8Id
# accuracy
# latitude
# longitude
# zipCode
# customZone

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# TODO
casa_cara=ds.loc[ds['price'].idxmax()]
address = casa_cara['address']
price = casa_cara['price']
print(f'La casa con dirección en {address} es la más cara y su precio es de {price} USD')
# Out:
# La casa con dirección en El Escorial es la más cara y su precio es de 8500000 USD

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# TODO
casa_barata=ds.loc[ds['price'].idxmin()]
direccion=casa_barata['address']
precio_b=casa_barata['price']
print(f'La casa con dirección en {direccion} es la más barata y su precio es de {precio_b} USD')
# Out:
# La casa con dirección en Parla es la más barata y su precio es de 0 USD

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
# TODO
casa_grande=ds.loc[ds['surface'].idxmax()]
direcciong=casa_grande['address']
superficieg=casa_grande['surface']

casa_pequeña=ds.loc[ds['surface'].idxmin()]
direccionp=casa_pequeña['address']
superficiep=casa_pequeña['surface']

print(f'La casa más grande esta ubicada en {direcciong} y su superficie es de {superficieg} metros')
print(f'La casa más pequeña esta ubicada en {direccionp} y su superficie es de {superficiep} metros')
# Out:
# La casa más grande esta ubicada en Sevilla la Nueva y su superficie es de 249000.0 metros
# La casa más pequeña esta ubicada en Calle Amparo,  Madrid Capital y su superficie es de 15.0 metros

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO
poblaciones_col5=ds['level5'].dropna().unique()
poblaciones_col5_str=', '.join(poblaciones_col5)
print(poblaciones_col5_str)
# Out:
# Arganda del Rey, Fuenlabrada, Boadilla del Monte, Las Rozas de Madrid,  Madrid Capital, Villaviciosa de Odón, Pinto, Valdemoro, Navalcarnero, Pozuelo de Alarcón, Torrejón de Ardoz, Navalagamella, San Sebastián de los Reyes, Rivas-vaciamadrid, Alpedrete, Móstoles, San Fernando de Henares, Coslada, Becerril de la Sierra, Alcalá de Henares, Chinchón, Parla, Alcorcón, El Escorial, Leganés, Pedrezuela, Majadahonda, Villanueva de la Cañada, Villanueva del Pardillo, Torrelodones, Moralzarzal, Mejorada del Campo, Aranjuez, Corpa, Getafe, Velilla de San Antonio, Sevilla la Nueva, San Martín de la Vega, Villalbilla, Collado Villalba, Alcobendas, El Molar (Madrid), Moraleja de Enmedio, Algete, Campo Real, Torrejón de la Calzada, Colmenar Viejo, Valdemorillo, Fuente El Saz de Jarama, Tres Cantos, Arroyomolinos (Madrid), Griñón, Paracuellos de Jarama, Guadarrama, Titulcia, Galapagar, Collado Mediano, Los Molinos, San Lorenzo de El Escorial, Loeches, San Martín de Valdeiglesias, Navas del Rey, Bustarviejo, Manzanares El Real, Carabaña, Casarrubuelos, Cercedilla, Fresnedillas de la Oliva, Valdemaqueda, Robledo de Chavela, Miraflores de la Sierra, Humanes de Madrid, Valdetorres de Jarama, San Agustín del Guadalix, Ciempozuelos, Camarma de Esteruelas, Torres de la Alameda, Talamanca de Jarama, El Atazar, Hoyo de Manzanares, El Boalo - Cerceda – Mataelpino, El Álamo, Valdilecha, Valdeolmos-Alalpardo, Guadalix de la Sierra, Belmonte de Tajo, El Vellón, Brunete, Redueña, Morata de Tajuña, Tielmes, Gargantilla del Lozoya, Meco, Venturada, Quijorna, Cenicientos, Torrejón de Velasco, Navacerrada, Santa María de la Alameda, Orusco de Tajuña, Daganzo de Arriba, Villamanta, Anchuelo, Valdaracete, Ajalvir, Los Santos de la Humosa, Villamanrique de Tajo, Colmenar de Oreja, Villa del Prado, Fuentidueña de Tajo, Colmenar del Arroyo, Valdelaguna, Cubas de la Sagra, Valdeavero, Aldea del Fresno, Ribatejada, Torrelaguna, Batres, Pezuela de las Torres, Colmenarejo, Serranillos del Valle, Cobeña, Soto del Real, El Berrueco, Villanueva de Perales, Fresno de Torote - Serracines, Pozuelo del Rey, Pelayos de la Presa, La Cabrera, Nuevo Baztán, Perales de Tajuña, Villaconejos, Villarejo de Salvanés, Cadalso de los Vidrios, Santorcaz, Madarcos, Garganta de los Montes, Puentes Viejas, Torremocha de Jarama, Valdemanco, Braojos, Lozoyuela-navas-sieteiglesias, Piñuécar-gandullas, Valdepiélagos, Valverde de Alcalá, Villar del Olmo, Villamantilla, Horcajo de la Sierra, Gascones, Zarzalejo, Villavieja del Lozoya, Brea de Tajo, Estremera, Chapinería, Navarredonda, Patones, Ambite, Navalafuente, Lozoya, Canencia, Cabanillas de la Sierra, Buitrago del Lozoya, Fresno de Torote, Robregordo, Pinilla del Valle, Rascafría, La Hiruela, Montejo de la Sierra

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
# TODO
tiene_na = ds.isna().any().any()
print(tiene_na)

if tiene_na:
    columnas_con_na = ds.columns[ds.isna().any()].tolist()
    print("Columnas con valores NAs:", columnas_con_na)
# Out:
# True
# Columnas con valores NAs: ['realEstate_name', 'phone_realEstate', 'rooms', 'bathrooms', 'surface', 'description', 'level4', 'level6', 'level7', 'level8', 'zipCode', 'customZone']

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
# TODO
dimensiones_antes = ds.shape

ds_sin_na = ds.dropna()

dimensiones_despues = ds_sin_na.shape
print(f"Dimensiones antes: {dimensiones_antes}")
print(f"Dimensiones después: {dimensiones_despues}")
# Out:
# Dimensiones antes: (15335, 37)
# Dimensiones después: (0, 37)

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
# TODO
filtro=ds['level5']  == "Arroyomolinos (Madrid)"
precios_Arroyomolinos = ds.loc[filtro,'price']
media_level5_Arroyomolinos=precios_Arroyomolinos.mean()
print(media_level5_Arroyomolinos)
# Out:
# 294541.59854014596

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
# TODO: Code
# TODO: Code
import pandas as pd
import matplotlib.pyplot as plt
data_frame=pd.read_csv('assets/real_estate.csv', sep=';')
Arroyomolinos=data_frame.loc[data_frame['level5']=="Arroyomolinos (Madrid)"]
plt.hist(Arroyomolinos['price'], bins=20,edgecolor='black')
plt.title("Histograma de precios Arroyomolinos (Madrid)")
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# **TODO: Markdown**. Observo que hay solo 2 casas menores de 50,000, la mayoría de las casas se concentran entre los 150,000 - 550,000; también se puede observar que hay 50 casas de un precio aproximado de 200,000 y 250,000 (20 por cada precio), siendo estas las de este tipo las que mas hay

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
# TODO
# TODO
import pandas as pd
data_frame=pd.read_csv('assets/real_estate.csv', sep=';')

Valdemorrillo_precio_promedio = data_frame.loc[data_frame["level5"]=="Valdemorrillo", "price"].mean()
Galapagar_precio_promedio = data_frame.loc[data_frame["level5"] == "Galapagar", "price"].mean()
if Valdemorrillo_precio_promedio == Galapagar_precio_promedio:
    print(f"Son iguales, y su precio promedio es de {Valdemorrillo_precio_promedio}")
else:
    print(f"No lo son, Valdemorrillo es {Valdemorrillo_precio_promedio} y Galapagar es de: {Galapagar_precio_promedio}")

print(data_frame[data_frame['level5'] == 'Valdemorrillo']['price'].isnull().sum())
# Out:
# No lo son, Valdemorrillo es nan y Galapagar es de: 360063.20238095237
# 0

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# TODO
import pandas as pd
data_frame=pd.read_csv('assets/real_estate.csv', sep=';')
data_frame['pps']=data_frame['price']/data_frame['surface']
promedio_valdemorrillo = data_frame.loc[data_frame['level5'] == "Valdemorrillo", 'pps'].mean()
promedio_galapagar = data_frame.loc[data_frame['level5'] == "Galapagar", 'pps'].mean()
print(f"Promedio de precio por metro cuadrado en Valdemorrillo: {promedio_valdemorrillo}")
print(f"Promedio de precio por metro cuadrado en Galapagar: {promedio_galapagar}")

if promedio_valdemorrillo == promedio_galapagar:
    print("Los promedios de precio por metro cuadrado de Valdemorrillo y Galapagar son iguales.")
else:
    print("Los promedios de precio por metro cuadrado de Valdemorrillo y Galapagar no son iguales.")
# Out:
# Promedio de precio por metro cuadrado en Valdemorrillo: nan
# Promedio de precio por metro cuadrado en Galapagar: 1606.3240303094024
# Los promedios de precio por metro cuadrado de Valdemorrillo y Galapagar no son iguales.

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
# TODO: Código
import pandas as pd
import matplotlib.pyplot as plt

data_frame=pd.read_csv('assets/real_estate.csv', sep=';')
plt.figure(figsize=(10,6))
plt.scatter(data_frame['surface'],data_frame['price'], alpha=0.7,color='blue')

plt.title('Relación entre la superficie y el precio de las casas')
plt.xlabel('Superficie')
plt.ylabel('Precio')
plt.show()

# %% [markdown]
# **TODO: Markdown**. La superficie incluye datos incorrectos o nulos

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# TODO
# TODO
import pandas as pd
data_frame=pd.read_csv('assets/real_estate.csv', sep=';')
num_agencias=data_frame['realEstate_name'].nunique()
print(num_agencias)
# Out:
# 1821

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# TODO
import pandas as pd
data_frame=pd.read_csv('assets/real_estate.csv', sep=';')
poblacion_mas_casas = data_frame['level5'].value_counts().idxmax()
numero_casas = data_frame['level5'].value_counts().max()

print(f"La población con más casas es: {poblacion_mas_casas}")
print(f"Número de casas en {poblacion_mas_casas}: {numero_casas}")
# Out:
# La población con más casas es:  Madrid Capital
# Número de casas en  Madrid Capital: 6643

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
# TODO
import pandas as pd
data_frame=pd.read_csv('assets/real_estate.csv', sep=';')
cinturon_sur=["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
data_cinturon_sur=data_frame[data_frame['level5'].isin(cinturon_sur)]
print(f"El número de casas en el cinturon sur es de {len(data_cinturon_sur)}")
# Out:
# El número de casas en el cinturon sur es de 907

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
# TODO: Code
import pandas as pd
import matplotlib.pyplot as plt
data_frame=pd.read_csv('assets/real_estate.csv', sep=';')
cinturon_sur=["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
data_cinturon_sur=data_frame[data_frame['level5'].isin(cinturon_sur)]
mediana_cinturon_sur=data_cinturon_sur.groupby('level5')['price'].median()

plt.figure(figsize=(10, 6))
mediana_cinturon_sur.plot(kind='bar', color=['skyblue', 'orange', 'green', 'purple'], edgecolor='black')
plt.title('Mediana de precios en el cinturón sur de Madrid', fontsize=16)
plt.xlabel('Población', fontsize=14)
plt.ylabel('Mediana de precios', fontsize=14)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **TODO: Markdown**. Getafe tiene la mediana de precios más alta, alrededor de 275,000, lo que indica que es más caro comprar una casa allí.
# Alorcón tiene la mediana de precios más baja, con unos 175,000, lo que sugiere que es la opción más asequible dentro del "Cinturón Sur".
# Las demás poblaciones (Fuenlabrada y Leganés) están en valores intermedios, siendo Fuenlabrada ligeramente más caro que Leganés.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# TODO
import pandas as pd
import matplotlib.pyplot as plt
data_frame=pd.read_csv('assets/real_estate.csv', sep=';')
cinturon_sur=["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
data_cinturon_sur=data_frame[data_frame['level5'].isin(cinturon_sur)]

#Precio
mediaprecio_cinturon_sur=data_cinturon_sur.groupby('level5')['price'].mean()
varianzaprecio_cinturon_sur=data_cinturon_sur.groupby('level5')['price'].var()
print(f"La media del precio es {mediaprecio_cinturon_sur}")
print(f"La varianza del precio es {varianzaprecio_cinturon_sur}")

#Habitaciones
mediahabitaciones_cinturon_sur=data_cinturon_sur.groupby('level5')['rooms'].mean()
varianzahabitaciones_cinturon_sur=data_cinturon_sur.groupby('level5')['rooms'].var()
print(f"La media de las habitaciones es {mediahabitaciones_cinturon_sur}")
print(f"La varianza de las habitaciones es {varianzahabitaciones_cinturon_sur}")

#Superficie
mediasuperficie_cinturon_sur=data_cinturon_sur.groupby('level5')['surface'].mean()
varianzasuperficie_cinturon_sur=data_cinturon_sur.groupby('level5')['surface'].var()
print(f"La media de la superficie es {mediasuperficie_cinturon_sur}")
print(f"La varianza de la superficie es {varianzasuperficie_cinturon_sur}")

#Baños
mediabaños_cinturon_sur=data_cinturon_sur.groupby('level5')['bathrooms'].mean()
varianzabaños_cinturon_sur=data_cinturon_sur.groupby('level5')['bathrooms'].var()
print(f"La media de las habitaciones es {mediabaños_cinturon_sur}")
print(f"La varianza de las habitaciones es {varianzabaños_cinturon_sur}")
# Out:
# La media del precio es level5
# Alcorcón       230071.052632
# Fuenlabrada    177198.021459
# Getafe         265040.500000
# Leganés        208682.010309
# Name: price, dtype: float64
# La varianza del precio es level5
# Alcorcón       1.594783e+10
# Fuenlabrada    4.701021e+09
# Getafe         2.098267e+10
# Leganés        1.191394e+10
# Name: price, dtype: float64
# La media de las habitaciones es level5
# Alcorcón       2.914894
# Fuenlabrada    3.025974
# Getafe         3.151724
# Leganés        2.906736
# Name: rooms, dtype: float64
# La varianza de las habitaciones es level5
# Alcorcón       0.933895
# Fuenlabrada    0.355844
# Getafe         0.772748
# Leganés        0.824590
# Name: rooms, dtype: float64
# La media de la superficie es level5
# Alcorcón       105.913295
# Fuenlabrada    103.624365
# Getafe         126.896266
# Leganés        105.852273
# Name: surface, dtype: float64
# La varianza de la superficie es level5
# Alcorcón       4244.323834
# Fuenlabrada    2264.643893
# Getafe         5828.110028
# Leganés        3987.475195
# Name: surface, dtype: float64
# La media de las habitaciones es level5
# Alcorcón       1.623656
# Fuenlabrada    1.445415
# Getafe         1.865052
# Leganés        1.518135
# Name: bathrooms, dtype: float64
# La varianza de las habitaciones es level5
# Alcorcón       0.592735
# Fuenlabrada    0.353367
# Getafe         0.658809
# Leganés        0.553055
# Name: bathrooms, dtype: float64

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# TODO
import pandas as pd
data_frame=pd.read_csv('assets/real_estate.csv', sep=';')
cinturon_sur=["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
data_cinturon_sur = data_frame[data_frame['level5'].isin(cinturon_sur)]
precio_casa_mas_cara = data_cinturon_sur.loc[data_cinturon_sur['price'].idxmax()]
direccion_cara = precio_casa_mas_cara['address']
print(f"La casa más cara en el cinturón sur vale {precio_casa_mas_cara['price']} y esta ubicada en {direccion_cara}")
# Out:
# La casa más cara en el cinturón sur vale 1050000 y esta ubicada en Getafe

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
# TODO
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

data_frame = pd.read_csv('assets/real_estate.csv', sep=';')
cinturon_sur = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
data_cinturon_sur = data_frame[data_frame['level5'].isin(cinturon_sur)]
scaler = MinMaxScaler()
data_cinturon_sur['precio_normalizado'] = scaler.fit_transform(data_cinturon_sur[['price']])

plt.figure(figsize=(10, 6))
for poblacion in cinturon_sur:
    subset = data_cinturon_sur[data_cinturon_sur['level5'] == poblacion]
    plt.hist(subset['precio_normalizado'], bins=20, alpha=0.5, label=poblacion)

plt.xlabel('Precio Normalizado')
plt.ylabel('Frecuencia')
plt.title('Histograma de Precios Normalizados por Población (Cinturón Sur)')
plt.legend(title='Población')
plt.show()
# Out:
# /tmp/ipykernel_1664/206465022.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cinturon_sur['precio_normalizado'] = scaler.fit_transform(data_cinturon_sur[['price']])

# %% [markdown]
# **TODO: Markdown**. En un precio normalizado de 0 a 1 podemos observar que es Getafe donde se encuentran la mayoría de las casas más baratas, siendo el mismo Getafe en donde se ubica la casa más cara

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
# TODO
import pandas as pd

data_frame = pd.read_csv('assets/real_estate.csv', sep=';')
data_frame['pps'] = data_frame['price'] / data_frame['surface']

GetafeAlcorcón = ['Getafe', 'Alcorcón']
data_GetafeAlcorcón = data_frame[data_frame['level5'].isin(GetafeAlcorcón)]

promedio_pps_getafe = data_GetafeAlcorcón[data_GetafeAlcorcón['level5'] == 'Getafe']['pps'].mean()
promedio_pps_alcorcon = data_GetafeAlcorcón[data_GetafeAlcorcón['level5'] == 'Alcorcón']['pps'].mean()

print(f"Promedio de precio por metro cuadrado en Getafe: {promedio_pps_getafe}")
print(f"Promedio de precio por metro cuadrado en Alcorcón: {promedio_pps_alcorcon}")

if promedio_pps_getafe > promedio_pps_alcorcon:
    print("El precio por metro cuadrado en Getafe es más alto que en Alcorcón.")
else:
    print("El precio por metro cuadrado en Alcorcón es más alto que en Getafe.")
# Out:
# Promedio de precio por metro cuadrado en Getafe: 2066.314949251463
# Promedio de precio por metro cuadrado en Alcorcón: 2239.302480199618
# El precio por metro cuadrado en Alcorcón es más alto que en Getafe.

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
# TODO
import pandas as pd
import matplotlib.pyplot as plt

data_frame = pd.read_csv('assets/real_estate.csv', sep=';')
cinturon_sur = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']
data_cinturon_sur = data_frame[data_frame['level5'].isin(cinturon_sur)]

fig, axs = plt.subplots(2, 2, figsize=(12, 10))
fig.suptitle('Precio vs Superficie por Población')

poblaciones = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']
for i, poblacion in enumerate(poblaciones):
    ax = axs[i // 2, i % 2]
    data_poblacion = data_cinturon_sur[data_cinturon_sur['level5'] == poblacion]
    ax.scatter(data_poblacion['surface'], data_poblacion['price'], alpha=0.7, label=poblacion)
    ax.set_title(poblacion)
    ax.set_xlabel('Superficie (m²)')
    ax.set_ylabel('Precio (€)')
    ax.legend()


plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en Madrid
map = Map(center = (40.35, -3.8), zoom = 11.5, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.OpenStreetMap.Mapnik)
map
# Out:
# Map(center=[40.35, -3.8], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…

# %%
## Aquí: traza la coordenadas de los estados

## PON TU CÓDIGO AQUÍ:

from ipyleaflet import Map, CircleMarker
import random

# Mapa centrado en el cinturón sur de Madrid
map = Map(center=(40.35, -3.8), zoom=11.5, min_zoom=1, max_zoom=20, basemap=basemaps.OpenStreetMap.Mapnik)

# Obtener coordenadas y población del cinturón sur
coordenadas = data_cinturon_sur[['latitude', 'longitude', 'level5']].dropna()

# Crear colores aleatorios para cada población
poblaciones = coordenadas['level5'].unique()
colores = {pob: f'#{random.randint(0, 0xFFFFFF):06x}' for pob in poblaciones}

# Agregar marcadores al mapa
for _, row in coordenadas.iterrows():
    marker = CircleMarker(
        location=(row['latitude'], row['longitude']),
        radius=5,
        color=colores[row['level5']],
        fill_color=colores[row['level5']],
        fill_opacity=0.7
    )
    map.add_layer(marker)

# Mostrar el mapa
map
# Out:
# Map(center=[40.35, -3.8], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…
